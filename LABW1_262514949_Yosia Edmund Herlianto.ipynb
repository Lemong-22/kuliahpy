# %% [markdown]
# # Week 1

# %% [markdown]
# ## Output

# %% [markdown]
# ## Coding Practice (In Google Colab, Submit the .ipynb)

# %%
nama = input("Masukkan nama lengkap : ")
umur = int(input("Masukkan Umur : "))
kota = input("Masukkan nama Kota : ")
fav_food = input("Masukkan makanan favorit : ")

print(f"Halo, perkenalkan, nama saya adalah {nama}, umur saya tahun ini adalah {umur} tahun. Saya berasal dari Kota {kota}. Makanan favorit saya adalah {fav_food}.")
# Out:
# Running cells with 'cpython-3.11.15-linux-x86_64-gnu (3.11.15) (Python 3.11.15)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/home/lemong/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
nim = int(input("Masukkan NIM : "))
nama = input("Masukkan nama : ")
prodi = input("Masukkan Program Studi : ")
kelas = input("Masukkan kelas yang diikuti : ")

print("=== Student Information ===")
print(f"Student ID: {nim}")
print(f"Name: {nama}")
print(f"Major: {prodi}")
print(f"Class: {kelas}")
